# %% [markdown]
# <a href="https://colab.research.google.com/github/leopriyam/SQL_Data_Analytics_Project/blob/main/1_Date_Format.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# If running in Google Colab, install PostgreSQL and restore the database
if 'google.colab' in sys.modules:
    # Update package installer
    # !sudo apt-get update -qq > /dev/null 2>&1

    # Install PostgreSQL
    # !sudo apt-get install postgresql -qq > /dev/null 2>&1

    # Start PostgreSQL service (suppress output)
    # !sudo service postgresql start > /dev/null 2>&1

    # Set password for the 'postgres' user to avoid authentication errors (suppress output)
    # !sudo -u postgres psql -c "ALTER USER postgres WITH PASSWORD 'password';" > /dev/null 2>&1

    # Create the 'colab_db' database (suppress output)
    # !sudo -u postgres psql -c "CREATE DATABASE contoso_100k;" > /dev/null 2>&1

    # Download the PostgreSQL .sql dump
    # !wget -q -O contoso_100k.sql https://github.com/lukebarousse/Int_SQL_Data_Analytics_Course/releases/download/v.0.0.0/contoso_100k.sql

    # Restore the dump file into the PostgreSQL database (suppress output)
    # !sudo -u postgres psql contoso_100k < contoso_100k.sql > /dev/null 2>&1

    # Shift libraries from ipython-sql to jupysql
    # !pip uninstall -y ipython-sql > /dev/null 2>&1
    # !pip install jupysql > /dev/null 2>&1

# Load the sql extension for SQL magic
# %load_ext sql

# Connect to the PostgreSQL database
# %sql postgresql://postgres:password@localhost:5432/contoso_100k

# Enable automatic conversion of SQL results to pandas DataFrames
# %config SqlMagic.autopandas = True

# Disable named parameters for SQL magic
# %config SqlMagic.named_parameters = "disabled"

# Display pandas number to two decimal places
pd.options.display.float_format = '{:.2f}'.format
# Out:
# Connecting to 'postgresql://postgres:***@localhost:5432/contoso_100k'

# %%
# %%sql
#
# SELECT
# 	orderdate,
# 	DATE_TRUNC('month', orderdate)::date AS order_month  -- cast to date
# FROM sales
# ORDER BY RANDOM()  -- get random rows
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 10 rows affected.
#     orderdate order_month
# 0  2020-04-15  2020-04-01
# 1  2022-01-08  2022-01-01
# 2  2023-05-17  2023-05-01
# 3  2023-12-20  2023-12-01
# 4  2023-06-21  2023-06-01
# 5  2015-05-02  2015-05-01
# 6  2022-05-18  2022-05-01
# 7  2024-04-17  2024-04-01
# 8  2018-12-08  2018-12-01
# 9  2021-05-03  2021-05-01

# %%
# %%sql
#
# SELECT
# 	DATE_TRUNC('month', s.orderdate)::date AS order_month,
# 	SUM(s.quantity * s.netprice / s.exchangerate) AS net_revenue
# FROM sales s
# GROUP BY
# 	order_month
# ORDER BY
# 	order_month
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 112 rows affected.
#     order_month  net_revenue
# 0    2015-01-01    492333.08
# 1    2015-02-01    754890.51
# 2    2015-03-01    380417.65
# 3    2015-04-01    166474.20
# 4    2015-05-01    615529.10
# ..          ...          ...
# 107  2023-12-01   2729676.08
# 108  2024-01-01   2605671.44
# 109  2024-02-01   3311112.34
# 110  2024-03-01   1639757.06
# 111  2024-04-01    464894.35
#
# [112 rows x 2 columns]

# %%
# %%sql
#
# SELECT
# 	DATE_TRUNC('month', s.orderdate)::date AS order_month,
# 	SUM(s.quantity * s.netprice / s.exchangerate) AS net_revenue,
# 	COUNT(DISTINCT s.customerkey) AS total_unique_customers
# FROM sales s
# GROUP BY
# 	order_month
# ORDER BY
# 	order_month
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 112 rows affected.
#     order_month  net_revenue  total_unique_customers
# 0    2015-01-01    492333.08                     200
# 1    2015-02-01    754890.51                     291
# 2    2015-03-01    380417.65                     139
# 3    2015-04-01    166474.20                      78
# 4    2015-05-01    615529.10                     236
# ..          ...          ...                     ...
# 107  2023-12-01   2729676.08                    1484
# 108  2024-01-01   2605671.44                    1340
# 109  2024-02-01   3311112.34                    1718
# 110  2024-03-01   1639757.06                     877
# 111  2024-04-01    464894.35                     246
#
# [112 rows x 3 columns]

# %%
# %%sql
#
# SELECT
# 	orderdate,
# 	TO_CHAR(orderdate, 'YYYY-MM') AS order_year_month
# FROM sales
# ORDER BY RANDOM()  -- get random rows
# LIMIT 10;
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 10 rows affected.
#     orderdate order_year_month
# 0  2019-05-13          2019-05
# 1  2019-02-12          2019-02
# 2  2019-10-05          2019-10
# 3  2023-02-23          2023-02
# 4  2020-01-04          2020-01
# 5  2018-08-07          2018-08
# 6  2023-03-21          2023-03
# 7  2022-05-11          2022-05
# 8  2020-03-19          2020-03
# 9  2017-10-26          2017-10

# %%
# %%sql
#
# SELECT
# 	TO_CHAR(s.orderdate, 'YYYY-MM') AS order_year_month,
# 	SUM(s.quantity * s.netprice * s.exchangerate) AS net_revenue
# FROM sales s
# GROUP BY
# 	order_year_month
# ORDER BY
# 	order_year_month
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 112 rows affected.
#     order_year_month  net_revenue
# 0            2015-01    384092.66
# 1            2015-02    706374.12
# 2            2015-03    332961.59
# 3            2015-04    160767.00
# 4            2015-05    548632.63
# ..               ...          ...
# 107          2023-12   2928550.93
# 108          2024-01   2677498.55
# 109          2024-02   3542322.55
# 110          2024-03   1692854.89
# 111          2024-04    483851.39
#
# [112 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['net_revenue'].plot(kind='hist', bins=20, title='net_revenue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['net_revenue'].plot(kind='line', figsize=(8, 4), title='net_revenue')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %%
# %%sql
#
# SELECT
# 	TO_CHAR(s.orderdate, 'YYYY-MM') AS order_year_month,
# 	SUM(s.quantity * s.netprice * s.exchangerate) AS net_revenue,
# 	COUNT(DISTINCT s.customerkey) AS total_unique_customers
# FROM sales s
# GROUP BY
# 	order_year_month
# ORDER BY
# 	order_year_month
# Out:
# Running query in 'postgresql://postgres:***@localhost:5432/contoso_100k'
# 112 rows affected.
#     order_year_month  net_revenue  total_unique_customers
# 0            2015-01    384092.66                     200
# 1            2015-02    706374.12                     291
# 2            2015-03    332961.59                     139
# 3            2015-04    160767.00                      78
# 4            2015-05    548632.63                     236
# ..               ...          ...                     ...
# 107          2023-12   2928550.93                    1484
# 108          2024-01   2677498.55                    1340
# 109          2024-02   3542322.55                    1718
# 110          2024-03   1692854.89                     877
# 111          2024-04    483851.39                     246
#
# [112 rows x 3 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_2['net_revenue'].plot(kind='hist', bins=20, title='net_revenue')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_3['total_unique_customers'].plot(kind='hist', bins=20, title='total_unique_customers')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_4.plot(kind='scatter', x='net_revenue', y='total_unique_customers', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_5['net_revenue'].plot(kind='line', figsize=(8, 4), title='net_revenue')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# _df_6['total_unique_customers'].plot(kind='line', figsize=(8, 4), title='total_unique_customers')
# plt.gca().spines[['top', 'right']].set_visible(False)
